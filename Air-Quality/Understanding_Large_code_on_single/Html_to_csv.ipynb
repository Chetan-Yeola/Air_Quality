# %%
import os
import sys

import pandas as pd
import requests
from bs4 import BeautifulSoup

final_data_df = pd.DataFrame() 

file_html = open('1.html', 'rb')
plain_text = file_html.read()

final_data = []
soup = BeautifulSoup(plain_text, "lxml")
for table in soup.findAll('table', {'class': 'medias mensuales numspan'}):
    for tr in table:
        temp_data = []
        for td in tr:
            text = td.get_text()
            temp_data.append(text)
        final_data.append(temp_data)
print(final_data)
# Out:
# [['Day', 'T', 'TM', 'Tm', 'SLP', 'H', 'PP', 'VV', 'V', 'VM', 'VG', 'RA', 'SN', 'TS', 'FG'], ['1', '9.1', '15.3', '4', '1015.6', '90', '0', '0.5', '0', '-', '-', '\xa0', '\xa0', '\xa0', 'o'], ['2', '7.4', '9.8', '4.8', '1017.6', '93', '0', '0.5', '4.3', '9.4', '-', '\xa0', '\xa0', '\xa0', 'o'], ['3', '7.8', '12.7', '4.4', '1018.5', '87', '0', '0.6', '4.4', '11.1', '-', '\xa0', '\xa0', '\xa0', 'o'], ['4', '', '', '', '', '', '', '', '', '', '', '\xa0', '\xa0', '\xa0', 'o'], ['5', '', '', '', '', '', '', '', '', '', '', '\xa0', '\xa0', '\xa0', 'o'], ['6', '', '', '', '', '', '', '', '', '', '', '\xa0', '\xa0', '\xa0', 'o'], ['7', '6.7', '13.4', '2.4', '1019.4', '82', '0', '0.6', '4.8', '11.1', '-', '\xa0', '\xa0', '\xa0', 'o'], ['8', '8.6', '15.5', '3.3', '1018.7', '72', '0', '0.8', '8.1', '20.6', '-', '\xa0', '\xa0', '\xa0', 'o'], ['9', '12.4', '20.9', '4.4', '1017.3', '61', '0', '1.3', '8.7', '22.2', '-', '\xa0', '\xa0', '\xa0', '\xa0'], ['10', '', '', '', '', '', '', '', '', '', '', '\xa0', '\xa0', '\xa0', '\xa0'], ['11', '', '', '', '', '', '', '', '', '', '', '\xa0', '\xa0', '\xa0', '\xa0'], ['12', '', '', '', '', '', '', '', '', '', '', '\xa0', '\xa0', '\xa0', '\xa0'], ['13', '16', '25.2', '10', '1013.2', '79', '0', '0.6', '4.8', '11.1', '-', '\xa0', '\xa0', '\xa0', 'o'], ['14', '13.4', '21', '9.2', '1015.1', '87', '0', '0.5', '1.5', '7.6', '-', '\xa0', '\xa0', '\xa0', 'o'], ['15', '14.3', '22.6', '6.6', '1016.3', '76', '0', '0.8', '0.4', '3.5', '-', '\xa0', '\xa0', '\xa0', 'o'], ['16', '', '', '', '', '', '', '', '', '', '', '\xa0', '\xa0', '\xa0', 'o'], ['17', '', '', '', '', '', '', '', '', '', '', 'o', '\xa0', 'o', '\xa0'], ['18', '', '', '', '', '', '', '', '', '', '', 'o', '\xa0', '\xa0', '\xa0'], ['19', '12.7', '18.9', '7.3', '1021.2', '76', '0', '1.8', '6.1', '16.5', '-', '\xa0', '\xa0', '\xa0', 'o'], ['20', '11.9', '18.9', '6.3', '1020.1', '76', '0', '1.1', '8.3', '20.6', '-', '\xa0', '\xa0', '\xa0', 'o'], ['21', '12.2', '19.9', '6.2', '1021', '69', '0', '2.1', '4.4', '18.3', '-', '\xa0', '\xa0', '\xa0', 'o'], ['22', '', '', '', '', '', '', '', '', '', '', '\xa0', '\xa0', '\xa0', 'o'], ['23', '', '', '', '', '', '', '', '', '', '', '\xa0', '\xa0', '\xa0', 'o'], ['24', '', '', '', '', '', '', '', '', '', '', '\xa0', '\xa0', '\xa0', '\xa0'], ['25', '13.4', '21.1', '5.6', '1020', '60', '0', '1.9', '8', '22.2', '-', '\xa0', '\xa0', '\xa0', '\xa0'], ['26', '12.3', '21.4', '6.4', '1019.6', '70', '0', '1.9', '6.7', '14.8', '-', '\xa0', '\xa0', '\xa0', '\xa0'], ['27', '13.7', '22', '7', '1018.2', '63', '0', '1.8', '7.2', '18.3', '-', '\xa0', '\xa0', '\xa0', '\xa0'], ['28', '', '', '', '', '', '', '', '', '', '', '\xa0', '\xa0', '\xa0', '\xa0'], ['29', '', '', '', '', '', '', '', '', '', '', '\xa0', '\xa0', '\xa0', '\xa0'], ['30', '', '', '', '', '', '', '', '', '', '', '\xa0', '\xa0', '\xa0', 'o'], ['31', '14.9', '21.9', '7.1', '1018.3', '73', '0', '0.6', '2', '7.6', '-', '\xa0', '\xa0', '\xa0', 'o'], ['Monthly means and totals:'], ['\xa0', '12.1', '19.7', '6.2', '1017.8', '75.1', '21.59', '1.1', '4.6', '16.1', '\xa0', '2', '0', '1', '19']]

# %%
monthly_data_df = pd.DataFrame(final_data[1:len(final_data) - 2], columns=final_data[0])
monthly_data_df
# Out:
#    Day     T    TM   Tm     SLP   H PP   VV    V    VM VG RA SN TS FG
# 0    1   9.1  15.3    4  1015.6  90  0  0.5    0     -  -           o
# 1    2   7.4   9.8  4.8  1017.6  93  0  0.5  4.3   9.4  -           o
# 2    3   7.8  12.7  4.4  1018.5  87  0  0.6  4.4  11.1  -           o
# 3    4                                                              o
# 4    5                                                              o
# 5    6                                                              o
# 6    7   6.7  13.4  2.4  1019.4  82  0  0.6  4.8  11.1  -           o
# 7    8   8.6  15.5  3.3  1018.7  72  0  0.8  8.1  20.6  -           o
# 8    9  12.4  20.9  4.4  1017.3  61  0  1.3  8.7  22.2  -
# 9   10
# 10  11
# 11  12
# 12  13    16  25.2   10  1013.2  79  0  0.6  4.8  11.1  -           o
# 13  14  13.4    21  9.2  1015.1  87  0  0.5  1.5   7.6  -           o
# 14  15  14.3  22.6  6.6  1016.3  76  0  0.8  0.4   3.5  -           o
# 15  16                                                              o
# 16  17                                                     o     o
# 17  18                                                     o
# 18  19  12.7  18.9  7.3  1021.2  76  0  1.8  6.1  16.5  -           o
# 19  20  11.9  18.9  6.3  1020.1  76  0  1.1  8.3  20.6  -           o
# 20  21  12.2  19.9  6.2    1021  69  0  2.1  4.4  18.3  -           o
# 21  22                                                              o
# 22  23                                                              o
# 23  24
# 24  25  13.4  21.1  5.6    1020  60  0  1.9    8  22.2  -
# 25  26  12.3  21.4  6.4  1019.6  70  0  1.9  6.7  14.8  -
# 26  27  13.7    22    7  1018.2  63  0  1.8  7.2  18.3  -
# 27  28
# 28  29
# 29  30                                                              o
# 30  31  14.9  21.9  7.1  1018.3  73  0  0.6    2   7.6  -           o

# %%
# drop unnecessary columns
col_idx_to_drop = [0, 4, 10, 11, 12, 13, 14]  
for col in reversed(col_idx_to_drop):
    monthly_data_df.drop(monthly_data_df.columns[col], axis=1, inplace=True)

# %%
monthly_data_df
# Out:
#        T    TM   Tm   H PP   VV    V    VM
# 0    9.1  15.3    4  90  0  0.5    0     -
# 1    7.4   9.8  4.8  93  0  0.5  4.3   9.4
# 2    7.8  12.7  4.4  87  0  0.6  4.4  11.1
# 3
# 4
# 5
# 6    6.7  13.4  2.4  82  0  0.6  4.8  11.1
# 7    8.6  15.5  3.3  72  0  0.8  8.1  20.6
# 8   12.4  20.9  4.4  61  0  1.3  8.7  22.2
# 9
# 10
# 11
# 12    16  25.2   10  79  0  0.6  4.8  11.1
# 13  13.4    21  9.2  87  0  0.5  1.5   7.6
# 14  14.3  22.6  6.6  76  0  0.8  0.4   3.5
# 15
# 16
# 17
# 18  12.7  18.9  7.3  76  0  1.8  6.1  16.5
# 19  11.9  18.9  6.3  76  0  1.1  8.3  20.6
# 20  12.2  19.9  6.2  69  0  2.1  4.4  18.3
# 21
# 22
# 23
# 24  13.4  21.1  5.6  60  0  1.9    8  22.2
# 25  12.3  21.4  6.4  70  0  1.9  6.7  14.8
# 26  13.7    22    7  63  0  1.8  7.2  18.3
# 27
# 28
# 29
# 30  14.9  21.9  7.1  73  0  0.6    2   7.6

# %%
final_data_df = final_data_df.append(monthly_data_df)

# %%
final_data_df
# Out:
#        T    TM   Tm   H PP   VV    V    VM
# 0    9.1  15.3    4  90  0  0.5    0     -
# 1    7.4   9.8  4.8  93  0  0.5  4.3   9.4
# 2    7.8  12.7  4.4  87  0  0.6  4.4  11.1
# 3
# 4
# 5
# 6    6.7  13.4  2.4  82  0  0.6  4.8  11.1
# 7    8.6  15.5  3.3  72  0  0.8  8.1  20.6
# 8   12.4  20.9  4.4  61  0  1.3  8.7  22.2
# 9
# 10
# 11
# 12    16  25.2   10  79  0  0.6  4.8  11.1
# 13  13.4    21  9.2  87  0  0.5  1.5   7.6
# 14  14.3  22.6  6.6  76  0  0.8  0.4   3.5
# 15
# 16
# 17
# 18  12.7  18.9  7.3  76  0  1.8  6.1  16.5
# 19  11.9  18.9  6.3  76  0  1.1  8.3  20.6
# 20  12.2  19.9  6.2  69  0  2.1  4.4  18.3
# 21
# 22
# 23
# 24  13.4  21.1  5.6  60  0  1.9    8  22.2
# 25  12.3  21.4  6.4  70  0  1.9  6.7  14.8
# 26  13.7    22    7  63  0  1.8  7.2  18.3
# 27
# 28
# 29
# 30  14.9  21.9  7.1  73  0  0.6    2   7.6
